# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import * 
import matplotlib.pyplot as plt

# %%
# Load the OCR letter recognition dataset
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data'
dataset = pd.read_csv(url, header=None)

# %%
# Split the dataset into features and labels
X = dataset.iloc[:, 1:].values  #selecting all rows and selecting all columns from index 1
y = dataset.iloc[:, 0].values   #selecting all rows and selecting column with index 0

# %%
print(y[0])
print(y[-1])
# Out:
# T
# A

# %%
# Encode the labels into numeric value
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
print(y[0])
print(y[-1])
# Out:
# 19
# 0

# %%
#splitting dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train = X_train / 15.0
X_test = X_test / 15.0

# %%
#we are using sequential model where layers are stacked one after another, 
#output of previous layer is given to as input to next layer

model = Sequential()
#1st layer is dense layer which consists on 128 neurons, since it is 1st layer we need to define input_shape of our training data
model.add(Dense(128, activation='relu', input_shape=(16,)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(26, activation='softmax'))  #softmax is used to predict multiclass category outcome
# Out:
# c:\Users\Rahul\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#now we will compile the model

#sparse_categorical_crossentropy (scce) produces a category index of the most likely matching category.
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics =['accuracy'])

# %%
#The batch size is a number of samples processed before the model is updated.
#verbose is the choice that how you want to see the output of your Nural Network while it's training. 
#If you set verbose = 0, It will show nothing
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=12, verbose=1)
# Out:
# Epoch 1/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 2s 762us/step - accuracy: 0.1256 - loss: 3.0022 - val_accuracy: 0.5523 - val_loss: 1.7736
# Epoch 2/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 663us/step - accuracy: 0.3861 - loss: 1.9588 - val_accuracy: 0.6233 - val_loss: 1.3811
# Epoch 3/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 653us/step - accuracy: 0.4808 - loss: 1.6373 - val_accuracy: 0.6780 - val_loss: 1.1961
# Epoch 4/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step - accuracy: 0.5278 - loss: 1.4996 - val_accuracy: 0.6942 - val_loss: 1.0866
# Epoch 5/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 661us/step - accuracy: 0.5577 - loss: 1.3938 - val_accuracy: 0.7048 - val_loss: 1.0414
# Epoch 6/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step - accuracy: 0.5684 - loss: 1.3499 - val_accuracy: 0.7260 - val_loss: 0.9698
# Epoch 7/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step - accuracy: 0.5896 - loss: 1.3041 - val_accuracy: 0.7225 - val_loss: 0.9357
# Epoch 8/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 671us/step - accuracy: 0.6037 - loss: 1.2448 - val_accuracy: 0.7340 - val_loss: 0.8889
# Epoch 9/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step - accuracy: 0.6156 - loss: 1.2186 - val_accuracy: 0.7470 - val_loss: 0.8721
# Epoch 10/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 657us/step - accuracy: 0.6244 - loss: 1.1795 - val_accuracy: 0.7552 - val_loss: 0.8333
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 643us/step - accuracy: 0.7086 - loss: 0.9244 - val_accuracy: 0.8310 - val_loss: 0.5921
# Epoch 45/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 646us/step - accuracy: 0.7132 - loss: 0.9018 - val_accuracy: 0.8338 - val_loss: 0.5600
# Epoch 46/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step - accuracy: 0.7098 - loss: 0.9120 - val_accuracy: 0.8405 - val_loss: 0.5680
# Epoch 47/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 649us/step - accuracy: 0.7079 - loss: 0.9055 - val_accuracy: 0.8300 - val_loss: 0.5756
# Epoch 48/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 647us/step - accuracy: 0.7064 - loss: 0.9200 - val_accuracy: 0.8405 - val_loss: 0.5534
# Epoch 49/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 642us/step - accuracy: 0.7109 - loss: 0.9020 - val_accuracy: 0.8380 - val_loss: 0.5528
# Epoch 50/50
# 1334/1334 ━━━━━━━━━━━━━━━━━━━━ 1s 659us/step - accuracy: 0.7142 - loss: 0.8982 - val_accuracy: 0.8415 - val_loss: 0.5527

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", accuracy)
print("Test loss:", loss)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.8412 - loss: 0.5596
# Test accuracy: 0.8414999842643738
# Test loss: 0.552692174911499

# %%
model.save('ocr_model.h5')
# Save the trained model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
model = load_model('ocr_model.h5')
# Load the trained model
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
sample_records = X_test[:1000]
# Select a few records for classification

# %%
# Perform classification
predictions = model.predict(sample_records)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
predicted_labels = np.argmax(predictions, axis=1)
predicted_letters = label_encoder.inverse_transform(predicted_labels)
actual_letters = label_encoder.inverse_transform(y_test)

# %%
# Calculate accuracy
accuracy = np.sum(predicted_labels == y[:1000]) / len(predicted_labels)

# %%
# Print the predicted labels and corresponding actual labels
print("Predicted Labels\tActual Labels")
for i in range(len(predicted_letters)):
    print(f"{predicted_letters[i]}\t\t\t{actual_letters[i]}")
# Out:
# Predicted Labels	Actual Labels
# D			D
# D			D
# V			V
# B			B
# H			H
# N			N
# E			E
# Q			Q
# X			R
# N			N
# Q			Q
# O			O
# N			N
# D			D
# J			I
# M			M
# U			U
# S			S
# O			O
# A			A
# X			X
# A			A
# K			K
# S			S
# O			O
# V			V
# Y			Y
# J			J
# D			D
# V			V
# H			D
# Y			V
# R			K
# F			F
# N			N
# I			I
# G			G
# T			T
# H			H
# K			K
# J			J
# O			O
# M			M
# T			T
# B			B
# Q			Q
# Z			Z
# C			C
# D			D
# X			X
# K			C
# G			G
# Q			Q
# F			F
# N			N
# Y			Y
# Z			Z
# K			K
# S			C
# K			T
# M			M
# W			V
# Q			G
# O			M
# D			D
# T			T
# H			H
# P			P
# N			N
# C			C
# O			O
# X			X
# D			X
# Q			Q
# V			V
# F			P
# V			V
# G			G
# W			W
# H			H
# P			P
# O			O
# I			I
# G			G
# X			X
# Y			X
# Y			P
# W			W
# O			Q
# D			D
# B			N
# G			Q
# T			T
# T			T
# V			V
# Y			Y
# T			T
# V			V
# J			J
# U			U
# D			D
# L			L
# M			M
# Y			Y
# E			E
# M			M
# A			A
# Y			Y
# K			K
# Y			Y
# U			U
# U			U
# U			U
# K			C
# Q			Q
# I			I
# A			A
# E			E
# D			D
# T			T
# B			P
# Q			Q
# Z			Z
# G			G
# X			X
# G			G
# F			F
# M			M
# S			S
# E			E
# E			E
# K			K
# Z			Z
# X			X
# O			O
# E			E
# U			U
# I			I
# R			R
# O			O
# M			M
# J			J
# F			F
# K			K
# M			M
# N			N
# O			T
# D			D
# H			H
# R			R
# L			L
# Z			Z
# F			F
# V			V
# W			W
# E			E
# T			T
# W			W
# Y			Y
# Q			Q
# L			L
# F			F
# O			O
# D			D
# K			K
# S			I
# X			X
# P			P
# H			H
# Q			Z
# D			H
# W			W
# F			F
# B			B
# R			R
# O			O
# B			B
# S			Z
# N			N
# W			W
# Z			Z
# W			W
# V			V
# B			S
# V			Y
# H			H
# Q			O
# T			Y
# V			V
# S			S
# W			W
# B			B
# P			P
# D			D
# Z			Z
# O			O
# X			X
# F			P
# B			B
# S			S
# T			T
# X			X
# J			J
# B			B
# Y			Y
# S			I
# Z			Z
# Z			Z
# P			P
# E			E
# R			H
# Q			Q
# F			I
# A			A
# H			H
# F			P
# E			E
# U			U
# K			K
# P			P
# M			M
# C			C
# X			Y
# J			J
# W			W
# M			M
# G			G
# J			J
# O			O
# V			H
# P			P
# L			L
# W			W
# A			A
# C			C
# C			C
# C			C
# O			O
# J			J
# Y			Y
# P			P
# Y			Y
# A			A
# R			R
# Z			Z
# J			J
# I			I
# G			G
# G			G
# I			I
# K			K
# R			M
# R			R
# T			T
# D			D
# E			E
# D			D
# L			L
# W			W
# G			P
# L			L
# U			U
# O			O
# T			T
# A			A
# V			V
# D			D
# U			U
# G			X
# X			X
# G			G
# C			C
# H			F
# Z			Z
# W			W
# T			T
# V			V
# T			T
# P			P
# M			M
# S			S
# U			U
# H			F
# Q			Q
# B			B
# Q			G
# K			K
# L			L
# F			F
# E			E
# R			R
# P			P
# R			R
# W			W
# I			I
# Y			Y
# Y			Y
# B			B
# C			C
# T			T
# M			M
# M			M
# O			N
# B			B
# R			R
# Z			Z
# G			G
# D			D
# R			R
# I			I
# Y			Y
# F			P
# M			M
# A			A
# B			B
# M			M
# R			F
# G			G
# Q			Q
# Z			Z
# P			P
# O			O
# Q			Q
# P			P
# O			G
# N			N
# O			O
# T			T
# G			G
# S			S
# V			V
# A			Z
# A			A
# P			P
# J			J
# O			O
# N			N
# Q			Q
# K			K
# X			X
# S			E
# F			P
# J			J
# N			N
# X			X
# X			X
# V			V
# Q			Q
# Y			H
# A			A
# T			T
# S			S
# W			W
# M			M
# P			P
# Y			Y
# R			U
# S			Z
# R			R
# B			B
# A			A
# Y			Y
# F			F
# F			F
# D			D
# A			A
# N			N
# A			A
# H			H
# Q			Q
# P			P
# Z			Z
# R			R
# D			D
# W			W
# R			O
# Q			Q
# K			K
# N			N
# W			W
# P			P
# W			W
# S			S
# K			K
# S			S
# I			J
# E			E
# S			S
# V			V
# S			S
# O			O
# V			V
# Q			T
# X			X
# Q			Q
# W			W
# I			I
# Z			Z
# D			D
# F			F
# P			P
# W			R
# O			P
# C			C
# D			D
# J			J
# R			L
# I			I
# D			H
# X			X
# R			D
# U			U
# G			G
# O			O
# K			K
# K			K
# K			K
# P			P
# P			P
# G			G
# T			T
# F			F
# B			B
# Y			Y
# V			Y
# I			I
# H			H
# E			E
# S			S
# Y			Y
# S			S
# T			T
# Q			Q
# L			L
# O			M
# I			I
# Z			Z
# F			F
# A			A
# J			J
# B			V
# G			G
# U			U
# Z			Z
# H			H
# O			O
# O			N
# S			J
# B			T
# O			O
# H			H
# Q			V
# F			F
# L			L
# W			W
# M			M
# T			Y
# J			J
# P			P
# W			W
# E			E
# A			A
# B			B
# W			N
# O			O
# Q			Q
# Y			Y
# Q			Q
# F			F
# A			A
# A			A
# Q			Q
# Z			Z
# E			E
# H			H
# N			N
# E			E
# A			A
# R			R
# G			C
# Z			Z
# Q			Q
# V			V
# O			O
# B			T
# K			K
# M			M
# R			R
# Y			Y
# X			X
# X			X
# J			J
# X			X
# Q			Q
# T			T
# S			S
# A			A
# X			X
# G			G
# T			T
# N			N
# S			S
# Y			Y
# P			P
# A			A
# S			I
# T			T
# O			X
# X			X
# C			C
# O			O
# B			B
# G			G
# R			W
# D			D
# K			K
# O			U
# S			S
# W			O
# Z			Z
# S			L
# W			N
# R			R
# V			V
# A			A
# K			L
# B			D
# W			W
# I			I
# B			O
# G			C
# W			W
# A			A
# Y			Y
# Q			Q
# L			L
# Q			Q
# K			K
# J			J
# E			E
# B			B
# P			P
# J			J
# R			R
# X			X
# N			N
# A			A
# G			G
# C			C
# H			T
# L			L
# S			S
# A			A
# N			N
# R			K
# V			V
# B			G
# A			A
# D			D
# H			H
# W			Y
# Z			Z
# Q			Q
# C			C
# U			U
# Q			Q
# Z			Z
# M			M
# D			D
# B			B
# L			L
# R			R
# R			Q
# D			D
# F			F
# W			W
# Q			Q
# M			M
# G			G
# Z			Z
# B			B
# U			U
# N			N
# K			K
# Q			P
# A			A
# W			U
# F			F
# T			T
# X			X
# L			L
# U			U
# Y			Y
# P			P
# Y			Y
# R			R
# S			S
# K			K
# G			E
# Q			Q
# F			F
# W			W
# Q			P
# P			P
# M			M
# N			N
# Z			Z
# G			G
# B			K
# O			O
# W			W
# I			I
# S			C
# E			E
# U			U
# R			R
# F			I
# Y			Y
# S			S
# V			V
# R			R
# C			C
# Q			Q
# C			C
# Z			J
# Y			Y
# S			S
# K			K
# G			L
# X			X
# T			T
# I			I
# F			F
# W			W
# A			A
# O			D
# K			K
# A			A
# Z			Z
# M			M
# G			G
# G			G
# W			W
# W			W
# Z			Z
# W			W
# T			T
# O			O
# R			R
# T			T
# N			N
# S			S
# Q			Q
# J			J
# Q			Q
# M			M
# O			O
# A			A
# N			N
# Z			Z
# D			D
# T			T
# S			I
# U			U
# A			A
# W			N
# O			G
# G			P
# L			L
# S			F
# R			R
# C			C
# P			P
# Y			Y
# Y			Y
# T			T
# A			A
# S			Y
# T			T
# Q			E
# T			T
# O			O
# S			S
# N			N
# O			O
# I			I
# O			O
# U			U
# N			N
# Z			Z
# J			J
# C			C
# N			H
# S			S
# G			L
# H			H
# E			C
# Q			Q
# F			F
# B			B
# W			O
# I			I
# K			K
# O			O
# B			R
# G			E
# L			L
# M			M
# L			L
# X			T
# E			E
# U			U
# W			W
# G			F
# D			D
# N			N
# V			V
# M			M
# I			I
# X			K
# L			L
# Y			Y
# Q			Q
# F			F
# U			U
# J			J
# V			V
# M			M
# P			P
# W			W
# L			L
# A			A
# L			L
# B			B
# Y			Y
# I			I
# D			D
# R			R
# T			T
# Q			Q
# B			B
# O			U
# M			M
# O			O
# I			I
# U			U
# U			U
# K			K
# S			J
# I			I
# O			W
# Z			Z
# Z			Z
# P			P
# A			A
# Z			Z
# P			P
# V			V
# O			G
# B			B
# G			G
# O			O
# V			V
# D			D
# Z			Z
# Y			Y
# P			P
# Q			Q
# A			A
# E			E
# W			W
# D			D
# J			J
# I			I
# J			J
# X			X
# B			S
# Z			Z
# Q			G
# X			T
# U			U
# K			K
# G			G
# I			I
# N			N
# Z			I
# W			W
# I			I
# I			I
# J			P
# B			B
# O			O
# H			H
# F			D
# O			O
# N			N
# Z			S
# D			D
# X			S
# M			M
# O			O
# W			N
# Y			Y
# S			X
# Q			Q
# W			M
# R			R
# G			G
# G			G
# A			A
# R			K
# U			U
# O			O
# B			P
# C			C
# V			V
# D			D
# B			B
# A			A
# E			E
# B			R
# T			T
# I			I
# S			Z
# N			N
# O			O
# S			B
# C			C
# G			G
# J			J
# E			E
# N			N
# J			J
# Q			H
# P			P
# O			O
# O			O
# B			B
# X			X
# R			D
# S			S
# O			O
# O			O
# G			G
# B			B
# R			H
# C			C
# A			A
# W			W
# P			P
# I			I
# N			N
# M			M
# K			G
# H			N
# A			A
# Q			H
# K			K
# N			N
# M			M
# F			F
# W			W
# A			A
# S			S
# E			E
# B			T
# J			J
# H			H
# N			N
# R			K
# W			W
# W			W
# U			U
# S			L
# Z			Z
# Z			Z
# Z			Z
# G			G
# T			T
# J			J
# V			V
# W			W
# L			L
# M			M
# U			U
# W			W
# Q			G
# A			A
# T			T
# J			J
# C			C
# G			G
# D			D
# T			Y
# Y			Y
# X			X
# N			N
# Y			Y
# S			S
# K			K
# U			U
# W			W
# R			R
# R			B
# T			T
# R			R
# H			H
# R			R
# M			M
# O			O
# W			W
# X			X
# R			R
# X			X
# N			N
# H			H
# C			C
# E			C
# J			J
# V			V
# V			V
# I			I
# R			R
# W			W
# V			H
# N			N
# E			E
# U			U
# A			M
# A			A
# B			B
# E			E
# K			K
# T			T
# F			F
# Y			Y
# D			T
# H			H
# W			W
# W			W
# O			O
# Q			G
# W			W
# L			L
# Q			Q
# R			R
# K			K
# D			D
# P			P
# T			T
# S			B
# B			L
# V			V
# Q			Q
# G			G
# B			S
# O			W
# V			V
# L			L
# D			D
# R			R
# L			L
# C			C
# N			N
# V			V
# I			I
# P			P
# K			C
# F			F
# W			W
# A			A
# P			P
# F			T
# H			H
# B			B
# K			K
# I			I
# W			W
# B			R
# J			J
# R			R
# K			K
# A			A
# Q			Q
# Q			Q
# A			A
# M			M
# V			V
# U			U
# G			G
# O			O
# U			U
# H			H
# V			V
# G			G
# Q			Q
# I			I
# T			T
# G			G
# P			I
